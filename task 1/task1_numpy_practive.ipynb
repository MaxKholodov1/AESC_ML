# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\3107362156.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %%
import numpy as np
def res1(m):
  diagonal=m.diagonal()
  n=diagonal[diagonal!=0]
  pr=np.prod(n)
  return pr

# %%
# code here
def res(x,n):
  ans=1
  for i in range(n):
    if(x[i][i]!=0):
      ans*=x[i][i]
  return ans;

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
# code here
import matplotlib.pyplot as plt
import time
import numpy as np
time_vectorized=[]
time_non_vectorized=[]
s=[1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000]
for i in range (len(s)):
  matr=np.random.randint(-5, 5, (s[i], s[i]))
  start1=time.time()
  res1(matr)
  end1= time.time()
  ans1=end1-start1
  start=time.time()
  res(matr, s[i])
  end= time.time()
  ans=end-start
  time_vectorized.append(ans1)
  time_non_vectorized.append(ans)
f, ax2 = plt.subplots(figsize=(10, 6))
ax2.plot(s, time_non_vectorized, label=u"Невекторизованная", marker='o')
ax2.plot(s, time_vectorized, label=u"Векторизованная", marker='o')
ax2.set_title(u"Сравнение времени выполнения")
ax2.set_xlabel(u"Размер матрицы")
ax2.set_ylabel(u"Время выполнения (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\348881831.py:6: RuntimeWarning: overflow encountered in scalar multiply
#   ans*=x[i][i]
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\24520639.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
def are_multisets_equalnonvect(x, y):
    x.sort()
    y.sort()
    if(len(x)!=len(y)):
        return False
    
    for i in range(len(x)):
        if(x[i]!=y[i]):
            return False
    return True

# %%
import numpy as np
def are_multisets_equalvect(x, y):
    np.sort(x)
    np.sort(y)
    if np.array_equal(x, y):
        return True
    else:
        return False

# %%
# code here
import matplotlib.pyplot as plt
import time
import numpy as np
time_vectorized=[]
time_non_vectorized=[]
s=[]
for i in range (1000, 1000000, 5000):
    s.append(i)
    x = np.random.randint(1, 101, size=i)
    y = np.random.randint(1, 101, size=i)
    startnonvect=time.time()
    are_multisets_equalnonvect(x, y)
    endnonvect= time.time()
    ansnonvect=endnonvect-startnonvect
    startvect=time.time()
    are_multisets_equalvect(x,y)
    endvect= time.time()
    ansvect=endvect-startvect
    time_vectorized.append(ansvect)
    time_non_vectorized.append(ansnonvect)
f, ax2 = plt.subplots(figsize=(10, 6))
ax2.plot(s, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(s, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Сравнение времени выполнения")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время выполнения (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\2282918483.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
# code here
def max_after_zerononvect(x):
    first = False
    mx=0
    for i in range(1, len(x)):
        if(first==False and x[i-1]==0):
            mx=x[i]
        else:
            if(x[i-1]==0 and x[i]>mx):
                mx=x[i]
    return mx

# %%
import numpy as np

def max_after_zerovect(x):
    zero_indices = np.where(x[:-1] == 0)[0]
    elements_after_zero = x[zero_indices + 1]
    return elements_after_zero.max() if elements_after_zero.size > 0 else 0

# %%
import matplotlib.pyplot as plt
import time
import numpy as np
time_vectorized=[]
time_non_vectorized=[]
s=[]
for i in range (1000, 100001, 100):
    s.append(i)
    x = np.random.randint(-50, 50, size=i)
    startnonvect=time.time()
    max_after_zerononvect(x)
    endnonvect= time.time()
    ansnonvect=endnonvect-startnonvect
    startvect=time.time()
    max_after_zerovect(x)
    endvect= time.time()
    ansvect=endvect-startvect
    time_vectorized.append(ansvect)
    time_non_vectorized.append(ansnonvect)
f, ax2 = plt.subplots(figsize=(10, 6))
ax2.plot(s, time_non_vectorized, label=u"Невекторизованная", marker='o')
ax2.plot(s, time_vectorized, label=u"Векторизованная", marker='o')
ax2.set_title(u"Сравнение времени выполнения")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время выполнения (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\4023105659.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
# code here

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
# code here
def run_length_encodingnon(x):
  
    values =[x[0]]
    counts=[1]
    for i in range(1, len(x)):
        if(x[i]==values[-1]):
            counts[-1]+=1
        else:
            values.append(x[i])
            counts.append(1)
    
    return values, counts

values, counts = run_length_encodingnon(x)

# %%
import numpy as np

def run_length_encodingvec(x):
    changes = np.where(np.diff(x) != 0)[0] + 1
    values = np.concatenate(([x[0]], x[changes]))
    counts = np.diff(np.concatenate(([0], changes, [len(x)])))
    return values, counts

# %%
import matplotlib.pyplot as plt
import time
import numpy as np
time_vectorized=[]
time_non_vectorized=[]
s=[]
for i in range (100000, 500000, 10000):
    s.append(i)
    x = np.random.randint(-50, 50, size=i)
    startnonvect=time.time()
    run_length_encodingnon(x)
    endnonvect= time.time()
    ansnonvect=endnonvect-startnonvect
    startvect=time.time()
    run_length_encodingvec(x)
    endvect= time.time()
    ansvect=endvect-startvect
    time_vectorized.append(ansvect)
    time_non_vectorized.append(ansnonvect)
f, ax2 = plt.subplots(figsize=(10, 6))
ax2.plot(s, time_non_vectorized, label=u"Невекторизованная", marker='o')
ax2.plot(s, time_vectorized, label=u"Векторизованная", marker='o')
ax2.set_title(u"Сравнение времени выполнения")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время выполнения (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\maksh\AppData\Local\Temp\ipykernel_13548\497016956.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
import numpy as np
def distnumpy(X, Y):
    return np.linalg.norm(X[:, np.newaxis, :] - Y[np.newaxis, :, :], axis=2)

# %%
import scipy
def euclidean_distance_scipy(X, Y):
    return scipy.spatial.distance.cdist(X, Y)

# %%
import numpy as np
import math
def distpy(X, Y):
    result = []
    for x in X:
        row = []
        for y in Y:
            dist = sum(math.sqrt((x[i][1]-y[i][1])**2+(x[i][2]-y[i][2])**2))
            row.append(dist)
        result.append(row)
    return result

# %%
import matplotlib.pyplot as plt
import time
import numpy as np

time_vectorized = []
time_non_vectorized = []
scipyy = []
s = []

for i in range(1000, 5001, 1000):
    np.random.seed(42)
    s.append(i)
    X = np.random.rand(i, 2)
    Y = np.random.rand(i, 2)
    
    startnonvect = time.time()
    distpy(X, Y)
    endnonvect = time.time()
    ansnonvect = endnonvect - startnonvect
    
    startvect = time.time()
    distnumpy(X, Y)
    endvect = time.time()
    ansvect = endvect - startvect

    startscipy = time.time()
    euclidean_distance_scipy(X, Y)
    endscipy= time.time()
    ansscipy = endscipy - startscipy
    

    
    time_vectorized.append(ansvect)
    time_non_vectorized.append(ansnonvect)
    scipyy.append(ansscipy)
    print(i)

f, ax2 = plt.subplots(figsize=(10, 6))
ax2.plot(s, time_non_vectorized, label=u"Невекторизованная", marker='o')
ax2.plot(s, time_vectorized, label=u"Векторизованная", marker='o')
ax2.plot(s, scipyy, label=u"scipy", marker='o')
ax2.set_title(u"Сравнение времени выполнения")
ax2.set_xlabel(u"Размер массива")
ax2.set_ylabel(u"Время выполнения (с)")
ax2.grid()
ax2.legend()

# Показать график
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 17
#      14 Y = np.random.rand(i, 2)
#      16 startnonvect = time.time()
# ---> 17 distpy(X, Y)
#      18 endnonvect = time.time()
#      19 ansnonvect = endnonvect - startnonvect
#
# Cell In[67], line 8, in distpy(X, Y)
#       6 row = []
#       7 for y in Y:
# ----> 8     dist = sum(math.sqrt((x[i][1]-y[i][1])**2+(x[i][2]-y[i][2])**2))
#       9     row.append(dist)
#      10 result.append(row)
#
# IndexError: index 1000 is out of bounds for axis 0 with size 2

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# ### Отчёт
# 1. скорость выполнения:
#     + большинство программ выполняются гораздо быстрее, если использовать библиотеку ***numpy***.
# 2. синтаксис:
#     + синтаксис библиотеки ***numpy*** ложнее, чем встроенный синтаксис языка.
# 3. сложность заданий:
#     + задания довольно *сложные*, поэтому я использовал интернет для поиска информации.
# *****
# **Вывод**:
#     Часто лучше использовать библиотеку ***numpy***, потому что она работает гораздо быстрее.
